# %% [markdown]
# RandomForestClassifier 데이터 모델 사용

# %% [markdown]
# 1.csv파일 불러오기(성공)

# %%
import pandas as pd
import numpy as np
from sklearn import datasets

file_path = "/Users/simmingyu/Downloads/iris.csv"
read = pd.read_csv(file_path)
data = pd.read_csv(file_path)
read
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2.훈련용 데이터와 실전용 데이터 나누기(성공)

# %%
from sklearn.model_selection import train_test_split

X = data['Name']
Y = data.drop(columns = 'Name')

X_train,X_test, Y_train, Y_test =train_test_split(X,Y,test_size = 0.3, random_state = 32)
print(X_train)
print(Y_train)
print(X_test)
print(Y_test)
# Out:
# 117     Iris-virginica
# 73     Iris-versicolor
# 97     Iris-versicolor
# 63     Iris-versicolor
# 49         Iris-setosa
#             ...
# 88     Iris-versicolor
# 124     Iris-virginica
# 54     Iris-versicolor
# 133     Iris-virginica
# 43         Iris-setosa
# Name: Name, Length: 105, dtype: object
#      SepalLength  SepalWidth  PetalLength  PetalWidth
# 117          7.7         3.8          6.7         2.2
# 73           6.1         2.8          4.7         1.2
# 97           6.2         2.9          4.3         1.3
# 63           6.1         2.9          4.7         1.4
# 49           5.0         3.3          1.4         0.2
# ..           ...         ...          ...         ...
# 88           5.6         3.0          4.1         1.3
# 124          6.7         3.3          5.7         2.1
# 54           6.5         2.8          4.6         1.5
# 133          6.3         2.8          5.1         1.5
# 43           5.0         3.5          1.6         0.6
#
# [105 rows x 4 columns]
# 55     Iris-versicolor
# 22         Iris-setosa
# 26         Iris-setosa
# 56     Iris-versicolor
# 134     Iris-virginica
# 131     Iris-virginica
# 23         Iris-setosa
# 34         Iris-setosa
# 85     Iris-versicolor
# 21         Iris-setosa
# 76     Iris-versicolor
# 115     Iris-virginica
# 60     Iris-versicolor
# 67     Iris-versicolor
# 147     Iris-virginica
# 113     Iris-virginica
# 66     Iris-versicolor
# 123     Iris-virginica
# 69     Iris-versicolor
# 10         Iris-setosa
# 44         Iris-setosa
# 107     Iris-virginica
# 138     Iris-virginica
# 12         Iris-setosa
# 13         Iris-setosa
# 95     Iris-versicolor
# 16         Iris-setosa
# 140     Iris-virginica
# 27         Iris-setosa
# 39         Iris-setosa
# 79     Iris-versicolor
# 38         Iris-setosa
# 41         Iris-setosa
# 144     Iris-virginica
# 98     Iris-versicolor
# 46         Iris-setosa
# 36         Iris-setosa
# 146     Iris-virginica
# 137     Iris-virginica
# 96     Iris-versicolor
# 15         Iris-setosa
# 102     Iris-virginica
# 33         Iris-setosa
# 143     Iris-virginica
# 5          Iris-setosa
# Name: Name, dtype: object
#      SepalLength  SepalWidth  PetalLength  PetalWidth
# 55           5.7         2.8          4.5         1.3
# 22           4.6         3.6          1.0         0.2
# 26           5.0         3.4          1.6         0.4
# 56           6.3         3.3          4.7         1.6
# 134          6.1         2.6          5.6         1.4
# 131          7.9         3.8          6.4         2.0
# 23           5.1         3.3          1.7         0.5
# 34           4.9         3.1          1.5         0.1
# 85           6.0         3.4          4.5         1.6
# 21           5.1         3.7          1.5         0.4
# 76           6.8         2.8          4.8         1.4
# 115          6.4         3.2          5.3         2.3
# 60           5.0         2.0          3.5         1.0
# 67           5.8         2.7          4.1         1.0
# 147          6.5         3.0          5.2         2.0
# 113          5.7         2.5          5.0         2.0
# 66           5.6         3.0          4.5         1.5
# 123          6.3         2.7          4.9         1.8
# 69           5.6         2.5          3.9         1.1
# 10           5.4         3.7          1.5         0.2
# 44           5.1         3.8          1.9         0.4
# 107          7.3         2.9          6.3         1.8
# 138          6.0         3.0          4.8         1.8
# 12           4.8         3.0          1.4         0.1
# 13           4.3         3.0          1.1         0.1
# 95           5.7         3.0          4.2         1.2
# 16           5.4         3.9          1.3         0.4
# 140          6.7         3.1          5.6         2.4
# 27           5.2         3.5          1.5         0.2
# 39           5.1         3.4          1.5         0.2
# 79           5.7         2.6          3.5         1.0
# 38           4.4         3.0          1.3         0.2
# 41           4.5         2.3          1.3         0.3
# 144          6.7         3.3          5.7         2.5
# 98           5.1         2.5          3.0         1.1
# 46           5.1         3.8          1.6         0.2
# 36           5.5         3.5          1.3         0.2
# 146          6.3         2.5          5.0         1.9
# 137          6.4         3.1          5.5         1.8
# 96           5.7         2.9          4.2         1.3
# 15           5.7         4.4          1.5         0.4
# 102          7.1         3.0          5.9         2.1
# 33           5.5         4.2          1.4         0.2
# 143          6.8         3.2          5.9         2.3
# 5            5.4         3.9          1.7         0.4

# %% [markdown]
# 3.데이터 업스케일링

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
Y_train_scaled = scaler.fit_transform(Y_train)
Y_test_scaled = scaler.fit_transform(Y_test)

# %% [markdown]
# 4.모델 작성

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier()
RF.fit(Y_train_scaled, X_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# 5.모델의 정확성 평가

# %%
from sklearn.metrics import accuracy_score

X_pred = RF.predict(Y_test_scaled)
accuracy = accuracy_score(X_test, X_pred)

print(f'accurate : {accuracy:.4f}')
# Out:
# accurate : 0.9111

# %% [markdown]
# 6.코드종합

# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

#csv파일 불러오기
file_path = "/Users/simmingyu/Downloads/iris.csv"
data = pd.read_csv(file_path)

#훈련용 데이터와 실전용 데이터 나누기
X = data['Name']
Y = data.drop(columns = 'Name')
X_train,X_test, Y_train, Y_test =train_test_split(X,Y,test_size = 0.3, random_state = 32)

#데이터 업스케일링
scaler = StandardScaler()
Y_train_scaled = scaler.fit_transform(Y_train)
Y_test_scaled = scaler.fit_transform(Y_test)

#인공지능 모델 설정(RandomForestClssifier)
RF = RandomForestClassifier()
RF.fit(Y_train_scaled, X_train)

#모델의 정확성 측정
X_pred = RF.predict(Y_test_scaled)
accuracy = accuracy_score(X_test, X_pred)
print(f'accurate : {accuracy:.4f}')
# Out:
# accurate : 0.9333

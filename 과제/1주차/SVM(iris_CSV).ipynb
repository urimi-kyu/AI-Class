# %% [markdown]
# SVM분류수행

# %% [markdown]
# 1.파일 읽어오기

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

file_path = "/Users/simmingyu/Downloads/iris.csv"
read = pd.read_csv(file_path)
read
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2.꽃의 종류를 그래프로 보여주기

# %%
sns.countplot(data = read, x = 'Name')
plt.title("iris.csv")
plt.xlabel("NAME")
plt.ylabel("COUNT")
data = pd.read_csv(file_path)

# %% [markdown]
# 3.훈련데이터와 실전데이터 나누기

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets

X= data['Name']
Y= data.drop(columns = 'Name')

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.3, random_state = 44)

# %% [markdown]
# 4.데이터 스케일링업

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
Y_train_scaled = scaler.fit_transform(Y_train)
Y_test_scaled = scaler.fit_transform(Y_test)

# %% [markdown]
# 5.모델 만들기 및 훈련

# %%
from sklearn.svm import SVC

SVM = SVC()
SVM.fit(Y_train_scaled, X_train)
# Out:
# SVC()

# %% [markdown]
# 6.모델의 정확성 측정

# %%
from sklearn.metrics import accuracy_score

X_pred = SVM.predict(Y_test_scaled)
accuracy = accuracy_score(X_test,X_pred)

print(f'accurate: {accuracy:.4f}')
# Out:
# accurate: 0.9778

# %% [markdown]
# DT분류수행

# %% [markdown]
# ##붓꽃데이터 읽기
# file_path = "*저장경로"
# df = pd.read_csv(file_path)
# 현재 내 컴퓨터의 csv의 파일 위치: /Users/simmingyu/Downloads/iris.csv

# %% [markdown]
# 1.파일을 불러와서 읽어보기(성공)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
file_path = "/Users/simmingyu/Downloads/iris.csv"
df = pd.read_csv(file_path)
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2.컬럼명을 확인해보기(성공)

# %%
df.columns
# Out:
# Index(['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Name'], dtype='object')

# %% [markdown]
# 3.꽃을 종류별로 보여주기(그래프)(성공)
# ##X축에는 꽃의 종류를,Y축에는 꽃의 개수를 나타내기)

# %%
sns.countplot(data = df, x = "Name")
plt.xlabel("Name")
plt.ylabel("Count")
plt.title("object")
# Out:
# Text(0.5, 1.0, 'object')

# %% [markdown]
# 4.scv파일을 데이터 셋으로 로드하기

# %%
file_path = "/Users/simmingyu/Downloads/iris.csv"
data = pd.read_csv(file_path)
data
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 데이터를 분류하기 -> 훈련용 데이터와 실전용데이터 분류

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets

X = data['Name']
Y = data.drop(columns = 'Name')

X_train,X_test,Y_train, Y_test = train_test_split(X,Y,test_size = 0.3, random_state = 44)
print(X_train)
print(Y_train)
print(X_test)
print(Y_test)
# Out:
# 145     Iris-virginica
# 39         Iris-setosa
# 140     Iris-virginica
# 60     Iris-versicolor
# 68     Iris-versicolor
#             ...
# 84     Iris-versicolor
# 96     Iris-versicolor
# 131     Iris-virginica
# 59     Iris-versicolor
# 20         Iris-setosa
# Name: Name, Length: 105, dtype: object
#      SepalLength  SepalWidth  PetalLength  PetalWidth
# 145          6.7         3.0          5.2         2.3
# 39           5.1         3.4          1.5         0.2
# 140          6.7         3.1          5.6         2.4
# 60           5.0         2.0          3.5         1.0
# 68           6.2         2.2          4.5         1.5
# ..           ...         ...          ...         ...
# 84           5.4         3.0          4.5         1.5
# 96           5.7         2.9          4.2         1.3
# 131          7.9         3.8          6.4         2.0
# 59           5.2         2.7          3.9         1.4
# 20           5.4         3.4          1.7         0.2
#
# ...

# %% [markdown]
# 5.훈련용 데이터와 실전용 데이터를 시각화 하기(성공)

# %%
sns.countplot(x= X_train)
plt.title('train')
plt.xlabel('Name')
plt.ylabel('count')
plt.show()


sns.countplot(x=X_test)
plt.title('test')
plt.xlabel('Name')
plt.ylabel('count')
plt.show()

# %% [markdown]
# 6.데이터 스케일링(성공)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
Y_train_scaled = scaler.fit_transform(Y_train)
Y_test_scaled = scaler.fit_transform(Y_test)

# %% [markdown]
# 7.모델 훈련

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()

DT.fit(Y_train_scaled,X_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# 8.모델의 정확도 측정

# %%
from sklearn.metrics import accuracy_score

X_pred = DT.predict(Y_test_scaled)
accuracy = accuracy_score(X_test, X_pred)
print(f'accurate : {accuracy:.4f}')
# Out:
# accurate : 0.8889

# %% [markdown]
# 9.코드 종합

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

#csv파일 읽어오기
file_path = "/Users/simmingyu/Downloads/iris.csv"
data = pd.read_csv(file_path)

#훈련용과 실전용 데이터 나누기
X = data['Name']
Y = data.drop(columns = 'Name')
X_train,X_test,Y_train, Y_test = train_test_split(X,Y,test_size = 0.3, random_state = 44)

#데이터 정교함을 위해 스케일링업
scaler = StandardScaler()
Y_train_scaled = scaler.fit_transform(Y_train)
Y_test_scaled = scaler.fit_transform(Y_test)

#인공지능 모델 설정 및 학습
DT = DecisionTreeClassifier()
DT.fit(Y_train_scaled,X_train)

#모델의 정확성 측정
X_pred = DT.predict(Y_test_scaled)
accuracy = accuracy_score(X_test, X_pred)
print(f'accurate : {accuracy:.4f}')
